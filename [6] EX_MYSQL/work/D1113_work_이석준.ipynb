# %%
import pandas as pd
from pandas import Series

# %%
pd.Series([100,200,300])
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
pd.Series(index=['철수','영희','아름'], data= [100,200,300])
# Out:
# 철수    100
# 영희    200
# 아름    300
# dtype: int64

# %%
pd.Series(index=['삼성전자','셀트리온','카카오','삼성전자우','현대바이오'], data= [	73000,
	356000,
	367000,
	68600,
	34150])
# Out:
# 삼성전자      73000
# 셀트리온     356000
# 카카오      367000
# 삼성전자우     68600
# 현대바이오     34150
# dtype: int64

# %%
data = [100, 200, 300]
index = ["철수", "영희", "아름"]
s = Series(data, index)
s.index
# Out:
# Index(['철수', '영희', '아름'], dtype='object')

# %%
s.values
# Out:
# array([100, 200, 300])

# %%
s.to_dict()
# Out:
# {'철수': 100, '영희': 200, '아름': 300}

# %%
s.to_excel('data.xlsx')

# %%
pd.read_excel('data.xlsx')
# Out:
#   Unnamed: 0    0
# 0         철수  100
# 1         영희  200
# 2         아름  300

# %%
s.dtype
# Out:
# dtype('int64')

# %%
data = [  10,  "가" ]
s = Series( data )
s.dtype
# Out:
# dtype('O')

# %%
s.index.dtype
# Out:
# dtype('int64')

# %%
data = {
    "2020-12-11": 73400,
    "2020-12-10": 72900,
    "2020-12-09": 73900,
    "2020-12-08": 71700,
    "2020-12-07": 72900
}
s = pd.Series(data)
s.name = '종가'
s.index.name = '날짜'
s
# Out:
# 날짜
# 2020-12-11    73400
# 2020-12-10    72900
# 2020-12-09    73900
# 2020-12-08    71700
# 2020-12-07    72900
# Name: 종가, dtype: int64

# %%
import pandas as pd

data = {"apple": 1500, "banana": 3000}
s = pd.Series(data)
s.to_dict()
# Out:
# {'apple': 1500, 'banana': 3000}

# %%
data = {"apple": 1500, "banana": 3000}
s = pd.Series(data)
s.index.name = 'icecream'
s
# Out:
# icecream
# apple     1500
# banana    3000
# dtype: int64

# %%
s = pd.Series(data=[1, 2, 3])
s.name = "number"
s
# Out:
# 0    1
# 1    2
# 2    3
# Name: number, dtype: int64

# %%
import numpy as np
s = pd.Series(data = [1.0,2.0,np.nan]).astype("float")
s
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
s = pd.Series([1, 2, 3])
s.to_numpy()
# Out:
# array([1, 2, 3])

# %%
print(s.array)
# Out:
# <NumpyExtensionArray>
# [1, 2, 3]
# Length: 3, dtype: int64
